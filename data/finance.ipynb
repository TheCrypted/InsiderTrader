# %%
import yfinance as yf

tech_etf = yf.Ticker("XLK")  # Technology Select Sector SPDR
health_etf = yf.Ticker("XLV")  # Healthcare Select Sector SPDR

print(tech_etf.info["longName"])
print(tech_etf.info["category"])
# Out:
# The Technology Select Sector SPDR Fund
# Technology
# yfinance.Ticker object <XLK>

# %%
tech_etf.history(start="2020-06-02", end="2020-06-07", interval="1d")
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2020-06-02 00:00:00-04:00  93.838723  94.527168  92.949483  94.527168
# 2020-06-03 00:00:00-04:00  94.909641  95.569395  94.498487  95.263420
# 2020-06-04 00:00:00-04:00  94.890517  95.550278  93.953472  94.479362
# 2020-06-05 00:00:00-04:00  95.148695  97.242707  94.986140  96.965424
#
#                              Volume  Dividends  Stock Splits  Capital Gains
# Date
# 2020-06-02 00:00:00-04:00  11207600        0.0           0.0            0.0
# 2020-06-03 00:00:00-04:00  11017900        0.0           0.0            0.0
# 2020-06-04 00:00:00-04:00   7569400        0.0           0.0            0.0
# 2020-06-05 00:00:00-04:00  10378200        0.0           0.0            0.0
